# %% [markdown]
# # T20 International Matches

# %% [markdown]
# This dataset contains 2,328 teams records.The indivisual Result by T20 international matches ,rest of columns contain information such as  team,score,overs,rpo,inns,result,opposition,ground,startdate.
#
# team: this column contain various teams.
#
# score: in this column information about score
#
# over: it give information about overs.
#
# inns: number of innings
#
# result: result
#
# opposition: it give information opposition team
#
# ground: ground
#
# startdate: match starting date.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("matches.csv")
df
# Out:
#               Team  Score  Overs   RPO  Inns Result     Opposition  \
# 0        Australia  214/5   20.0  10.7     1    won  v New Zealand
# 1      New Zealand    170   20.0   8.5     2   lost    v Australia
# 2          England  179/8   20.0  8.95     1    won    v Australia
# 3        Australia     79   14.3  5.44     2   lost      v England
# 4     South Africa    133   19.3  6.82     1   lost  v New Zealand
# ...            ...    ...    ...   ...   ...    ...            ...
# 2323    Luxembourg  165/4   18.4  8.83     2    won   v Czech Rep.
# 2324       Austria  179/5   20.0  8.95     1   lost   v Luxembourg
# 2325    Luxembourg  180/5   19.4  9.15     2    won      v Austria
# 2326    Czech Rep.  156/4   17.0  9.17     1   lost      v Austria
# 2327       Austria  161/6   16.2  9.85     2    won   v Czech Rep.
#
#             Ground Start Date
# 0         Auckland  17-Feb-05
# 1         Auckland  17-Feb-05
# 2      Southampton  13-Jun-05
# 3      Southampton  13-Jun-05
# ...

# %% [markdown]
# # To check the head of the DataFrame.

# %%
df.head()
# Out:
#            Team  Score  Overs   RPO  Inns Result     Opposition        Ground  \
# 0     Australia  214/5   20.0  10.7     1    won  v New Zealand      Auckland
# 1   New Zealand    170   20.0   8.5     2   lost    v Australia      Auckland
# 2       England  179/8   20.0  8.95     1    won    v Australia   Southampton
# 3     Australia     79   14.3  5.44     2   lost      v England   Southampton
# 4  South Africa    133   19.3  6.82     1   lost  v New Zealand  Johannesburg
#
#   Start Date
# 0  17-Feb-05
# 1  17-Feb-05
# 2  13-Jun-05
# 3  13-Jun-05
# 4  21-Oct-05

# %% [markdown]
# # Use the .info() method to find out how many entries there are.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2328 entries, 0 to 2327
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        2328 non-null   object
#  1   Score       2328 non-null   object
#  2   Overs       2328 non-null   float64
#  3   RPO         2328 non-null   object
#  4   Inns        2328 non-null   int64
#  5   Result      2328 non-null   object
#  6   Opposition  2328 non-null   object
#  7   Ground      2328 non-null   object
#  8   Start Date  2328 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 163.8+ KB

# %% [markdown]
# # Use the .describe() method to find out descriptive statestics.

# %%
df.describe()
# Out:
#              Overs         Inns
# count  2328.000000  2328.000000
# mean     18.177534     1.479811
# std       3.690930     0.522404
# min       0.000000     0.000000
# 25%      18.200000     1.000000
# 50%      20.000000     1.000000
# 75%      20.000000     2.000000
# max      20.000000     2.000000

# %% [markdown]
# # Use the .describe() method to find out descriptive statistics for including objects.

# %%
df.describe(include="object")
# Out:
#             Team Score   RPO Result  Opposition       Ground Start Date
# count       2328  2328  2328   2328        2328         2328       2328
# unique        75  1039   572      4          75          141        805
# top     Pakistan   DNB  6.75    won  v Pakistan  Dubai (DSC)  27-Oct-19
# freq         170    27    30   1114         170          124         16

# %% [markdown]
# # Use the .isna() method to find out the missing values.

# %%
df.isna()
# Out:
#        Team  Score  Overs    RPO   Inns  Result  Opposition  Ground  \
# 0     False  False  False  False  False   False       False   False
# 1     False  False  False  False  False   False       False   False
# 2     False  False  False  False  False   False       False   False
# 3     False  False  False  False  False   False       False   False
# 4     False  False  False  False  False   False       False   False
# ...     ...    ...    ...    ...    ...     ...         ...     ...
# 2323  False  False  False  False  False   False       False   False
# 2324  False  False  False  False  False   False       False   False
# 2325  False  False  False  False  False   False       False   False
# 2326  False  False  False  False  False   False       False   False
# 2327  False  False  False  False  False   False       False   False
#
#       Start Date
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 2323       False
# ...

# %% [markdown]
# # Use the .isna().sum() method to find out the number of missing values.

# %%
df.isna().sum()
# Out:
# Team          0
# Score         0
# Overs         0
# RPO           0
# Inns          0
# Result        0
# Opposition    0
# Ground        0
# Start Date    0
# dtype: int64

# %% [markdown]
# # Use the .unique()method to find out the unique values.

# %%
df.Ground.unique()
# Out:
# array(['Auckland', 'Southampton', 'Johannesburg', 'Brisbane', 'Bristol',
#        'Khulna', 'Wellington', 'Sydney', 'The Oval', 'Nairobi (Gym)',
#        'Durban', 'Cape Town', 'Mumbai (BS)', 'Perth', 'Port Elizabeth',
#        'Melbourne', 'Christchurch', 'Karachi', 'Manchester', 'Bridgetown',
#        'Belfast', 'King City (NW)', 'Hamilton', 'Colombo (RPS)',
#        'Port of Spain', 'Centurion', 'Dubai (DSC)', "Lord's",
#        'Nottingham', 'Basseterre', 'Nagpur', 'Mohali', 'Colombo (PSS)',
#        'Colombo (SSC)', 'Abu Dhabi', 'Hobart', 'Providence', 'Gros Islet',
#        'North Sound', 'Lauderhill', 'Harare', 'Birmingham', 'Cardiff',
#        'Bloemfontein', 'Kimberley', 'Adelaide', 'Pallekele', 'Dhaka',
#        'Kolkata', 'Mombasa', 'ICCA Dubai', 'Hambantota', 'The Hague',
#        'Chester-le-Street', 'Chennai', 'Pune', 'Mumbai', 'East London',
#        'Bengaluru', 'Ahmedabad', 'Sharjah', 'Windhoek', 'Bulawayo',
# ...

# %% [markdown]
# # Use the .nunique() method to find out the number of unique values.

# %%
df.Ground.nunique()
# Out:
# 141

# %%
df.mean()
# Out:
# Overs    18.177534
# Inns      1.479811
# dtype: float64

# %%
df.mode()
# Out:
#        Team Score  Overs   RPO  Inns Result  Opposition       Ground  \
# 0  Pakistan   DNB   20.0  6.75   1.0   lost  v Pakistan  Dubai (DSC)
# 1       NaN   NaN    NaN   NaN   NaN    won         NaN          NaN
#
#   Start Date
# 0  27-Oct-19
# 1        NaN

# %%
df.median()
# Out:
# Overs    20.0
# Inns      1.0
# dtype: float64

# %%
df.std()
# Out:
# Overs    3.690930
# Inns     0.522404
# dtype: float64

# %%
df.var()
# Out:
# Overs    13.622963
# Inns      0.272906
# dtype: float64

# %% [markdown]
# # Use the .value_counts() method to find out the relative frequency.

# %%
df.Score.value_counts()
# Out:
# DNB      27
# 135/7    12
# 141/7    10
# 146/7    10
# 160/6     9
#          ..
# 65/5      1
# 144/5     1
# 209/2     1
# 143/7     1
# 178/2     1
# Name: Score, Length: 1039, dtype: int64

# %%
df.Ground.value_counts()
# Out:
# Dubai (DSC)           124
# Abu Dhabi              96
# Dhaka                  88
# Al Amerat              84
# Colombo (RPS)          72
#                      ...
# Dunedin                 2
# Dublin                  2
# Hyderabad (Deccan)      2
# Paarl                   2
# St George's             2
# Name: Ground, Length: 141, dtype: int64

# %%
df.Team.value_counts()
# Out:
# Pakistan        170
# New Zealand     145
# India           142
# Australia       136
# South Africa    131
#                ...
# Costa Rica        3
# Serbia            2
# Bhutan            2
# Isle of Man       1
# ICC World XI      1
# Name: Team, Length: 75, dtype: int64

# %%
df.sort_values("Result")
# Out:
#               Team  Score  Overs    RPO  Inns Result      Opposition  \
# 1163   Netherlands    141   19.2   7.29     2   lost      v Scotland
# 963     Bangladesh  156/6   20.0    7.8     2   lost      v Zimbabwe
# 961       Zimbabwe  125/8   20.0   6.25     2   lost    v Bangladesh
# 1867         Malta    136   18.2   7.41     2   lost    v Czech Rep.
# 958       Pakistan  168/7   20.0    8.4     1   lost   v New Zealand
# ...            ...    ...    ...    ...   ...    ...             ...
# 1039     Australia  205/5   20.0  10.25     2    won  v South Africa
# 1037  South Africa  158/7   19.2   8.17     2    won     v Australia
# 1035      Pakistan  151/4   19.2   7.81     2    won     v Sri Lanka
# 1052      Zimbabwe  147/7   20.0   7.35     1    won      v Scotland
# 2327       Austria  161/6   16.2   9.85     2    won    v Czech Rep.
#
#             Ground Start Date
# 1163     Abu Dhabi  17-Jan-17
# 963         Khulna  20-Jan-16
# 961         Khulna  17-Jan-16
# ...

# %%
df.sort_values(["Opposition","Team","Score","RPO"])
# Out:
#              Team  Score  Overs   RPO  Inns Result     Opposition  \
# 1333   Bangladesh    122   19.0  6.42     2   lost  v Afghanistan
# 1334   Bangladesh  134/8   20.0   6.7     1   lost  v Afghanistan
# 1765   Bangladesh    139   19.5     7     2   lost  v Afghanistan
# 1783   Bangladesh  139/6   19.0  7.31     2    won  v Afghanistan
# 1337   Bangladesh  144/6   20.0   7.2     2   lost  v Afghanistan
# ...           ...    ...    ...   ...   ...    ...            ...
# 524     Sri Lanka  182/4   20.0   9.1     1    won     v Zimbabwe
# 750        U.A.E.  116/9   20.0   5.8     1   lost     v Zimbabwe
# 609   West Indies  131/2   16.1   8.1     2    won     v Zimbabwe
# 614   West Indies  158/7   20.0   7.9     1    won     v Zimbabwe
# 299   West Indies   79/7   20.0  3.95     2   lost     v Zimbabwe
#
#              Ground Start Date
# 1333       Dehradun   3-Jun-18
# 1334       Dehradun   5-Jun-18
# 1765          Dhaka  15-Sep-19
# 1783     Chattogram  21-Sep-19
# ...

# %%
df[df.Overs<=19.0]
# Out:
#               Team  Score  Overs    RPO  Inns Result      Opposition  \
# 3        Australia     79   14.3   5.44     2   lost       v England
# 5      New Zealand  134/5   18.0   7.44     2    won  v South Africa
# 7     South Africa    114   18.3   6.16     2   lost     v Australia
# 15        Pakistan  148/5   17.5   8.29     2    won       v England
# 21       Sri Lanka   62/1    5.5  10.62     2    won   v New Zealand
# ...            ...    ...    ...    ...   ...    ...             ...
# 2319       Austria   59/3    7.3   7.86     2    won    v Luxembourg
# 2321    Czech Rep.     84   18.1   4.62     2   lost       v Austria
# 2323    Luxembourg  165/4   18.4   8.83     2    won    v Czech Rep.
# 2326    Czech Rep.  156/4   17.0   9.17     1   lost       v Austria
# 2327       Austria  161/6   16.2   9.85     2    won    v Czech Rep.
#
#             Ground Start Date
# 3      Southampton  13-Jun-05
# 5     Johannesburg  21-Oct-05
# 7         Brisbane   9-Jan-06
# ...

# %%
df[df.Inns==2]["Score"]
# Out:
# 1         170
# 3          79
# 5       134/5
# 7         114
# 9       126/8
#         ...
# 2319     59/3
# 2321       84
# 2323    165/4
# 2325    180/5
# 2327    161/6
# Name: Score, Length: 1144, dtype: object

# %%
df[(df.Overs==17.0)|(df.Overs==18.0)]
# Out:
#               Team  Score  Overs    RPO  Inns Result      Opposition  \
# 5      New Zealand  134/5   18.0   7.44     2    won  v South Africa
# 47      Bangladesh  165/4   18.0   9.16     2    won   v West Indies
# 129    Netherlands  110/5   18.0   6.11     2    won      v Scotland
# 136       Zimbabwe  106/8   17.0   6.23     1   lost     v Sri Lanka
# 159   South Africa    130   18.0   7.22     2   lost     v Australia
# 171    West Indies  123/4   18.0   6.83     2    won       v England
# 200        Ireland  112/8   18.0   6.22     1   lost         v India
# 223    New Zealand    110   17.0   6.47     2   lost     v Sri Lanka
# 353        England  148/3   17.0    8.7     2    won     v Australia
# 365          India  144/3   18.0      8     2    won      v Zimbabwe
# 424    New Zealand  187/3   18.0  10.38     1    won      v Zimbabwe
# 503     Bangladesh    128   18.0   7.11     2   lost      v Scotland
# 505     Bangladesh  145/2   18.0   8.05     2    won   v Netherlands
# ...

# %%
df.Overs[(df.Overs==17.0)|(df.Overs==18.0)]
# Out:
# 5       18.0
# 47      18.0
# 129     18.0
# 136     17.0
# 159     18.0
# 171     18.0
# 200     18.0
# 223     17.0
# 353     17.0
# 365     18.0
# 424     18.0
# 503     18.0
# 505     18.0
# 509     18.0
# 563     17.0
# 733     17.0
# 739     18.0
# 802     18.0
# 991     18.0
# 996     18.0
# 1055    18.0
# 1080    18.0
# 1147    18.0
# 1195    18.0
# 1197    18.0
# 1213    18.0
# 1390    18.0
# 1391    18.0
# 1422    17.0
# 1423    17.0
# 1433    17.0
# 1447    17.0
# 1549    18.0
# 1555    18.0
# 1585    17.0
# 1617    17.0
# 1627    17.0
# 1665    18.0
# 1760    18.0
# 1792    18.0
# 1793    18.0
# 1812    18.0
# 1816    18.0
# 1817    18.0
# 1822    18.0
# 1823    18.0
# 1824    18.0
# 1825    18.0
# 1828    18.0
# 1830    18.0
# 1861    18.0
# 1887    17.0
# 1893    17.0
# 1965    17.0
# 2125    17.0
# 2155    17.0
# 2293    18.0
# 2326    17.0
# Name: Overs, dtype: float64

# %%
df[df.Overs.isin([15,16])]
# Out:
#               Team  Score  Overs    RPO  Inns Result      Opposition  \
# 109     Bangladesh    101   16.0   6.31     2   lost      v Pakistan
# 137      Sri Lanka  107/5   16.0   6.68     2    won      v Zimbabwe
# 295      Australia  119/4   16.0   7.43     2    won   v New Zealand
# 323    Afghanistan     80   16.0      5     2   lost  v South Africa
# 349        England  132/3   16.0   8.25     2    won     v Sri Lanka
# 363          India  112/4   15.0   7.46     2    won      v Zimbabwe
# 443   South Africa  174/2   16.0  10.87     2    won   v New Zealand
# 599      Australia  119/3   15.0   7.93     2   lost     v Sri Lanka
# 729      Australia  129/4   15.0    8.6     2    won  v South Africa
# 803    New Zealand  117/4   15.0    7.8     2    won   v West Indies
# 1040    Bangladesh  120/5   15.0      8     1   lost         v India
# 1222   West Indies  112/3   15.0   7.46     1    won   v Afghanistan
# 1265     Sri Lanka     87   16.0   5.43     2   lost         v India
# ...

# %%
df.groupby("Ground").mean().Overs
# Out:
# Ground
# Aberdeen         19.200000
# Abu Dhabi        19.023958
# Adelaide         19.630000
# Ahmedabad        19.250000
# Al Amerat        17.886905
#                    ...
# Visakhapatnam    17.875000
# Walferdange      19.458333
# Waterloo         18.733333
# Wellington       18.423333
# Windhoek         18.094444
# Name: Overs, Length: 141, dtype: float64

# %%
df.groupby("Result").agg(["min","max","mean"]).Overs.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Result'>

# %%
df.groupby("Result").mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Result'>

# %%
df['Overs'].hist(bins=10)   

plt.title("Overs frequency distribution")
plt.xlabel("Overs")
plt.ylabel("frequency")
plt.show()

# %%
mwidth = df['Overs'].mean()
mdwidth = df['Overs'].median()

df['Overs'].hist(bins=10)
plt.axvline(mwidth, color="red")
plt.axvline(mdwidth, color="yellow")

plt.title("Overs frequency distribution")
plt.xlabel("Overs")
plt.ylabel("frequency")
plt.show()

# %%
df.Result.value_counts().plot(kind='bar')

plt.title("Result count bar plot")
plt.xlabel("Result")
plt.ylabel("count")
plt.show()

# %%
df.Result.value_counts().plot(kind='barh')

plt.title("Result count bar plot")
plt.xlabel("Result")
plt.ylabel("count")
plt.show()

# %%
df["Result"].value_counts().plot.pie(
    autopct="%1.1f%%", explode=(0,0,0.1,0))

plt.show()

# %%
plt.scatter(x=df["Overs"], y=df["Result"], color="red")

plt.title("scatter plot")
plt.xlabel("Overs")
plt.ylabel("Result")
plt.show()

# %%
sns.distplot(df["Overs"])
# Out:
# <AxesSubplot:xlabel='Overs', ylabel='Density'>

# %%
mwidth = df['Overs'].mean()  
dwidth = df['Overs'].median()

sns.distplot(df["Overs"])
plt.axvline(mwidth, color="red")
plt.axvline(dwidth, color="yellow")
plt.grid(True)

# %%
sns.countplot(data=df, x="Result")  
plt.grid(True)

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x="Result")
plt.grid(True)

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x="Result", hue="Inns")
plt.grid(True)

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_17861_row0_col0,#T_17861_row1_col1{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_17861_row0_col1,#T_17861_row1_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_17861_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Overs</th>        <th class="col_heading level0 col1" >Inns</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17861_level0_row0" class="row_heading level0 row0" >Overs</th>
#                         <td id="T_17861_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_17861_row0_col1" class="data row0 col1" >-0.098401</td>
#             </tr>
#             <tr>
#                         <th id="T_17861_level0_row1" class="row_heading level0 row1" >Inns</th>
# ...

# %% [markdown]
# # Conclusion:

# %%
To conclude that maximum matches lost or won in 
between 17 to 20 overs.
Both lost and won matches are percentage is 95.8 and tie maches are 4.2.
